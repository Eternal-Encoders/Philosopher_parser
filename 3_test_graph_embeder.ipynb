# %%
import torch
import pickle
import numpy as np
import networkx as nx
from PIL import ImageChops
from sentence_transformers import SentenceTransformer
from src import TypeReturn

# %%
m_path = 'google/embeddinggemma-300m'

# %%
model = SentenceTransformer(
    m_path,
    model_kwargs={
        'dtype': torch.bfloat16,
        'device_map': 'auto'
    }
)

model = torch.compile(
    model,
    mode='max-autotune',
    fullgraph=True
)

# %%
with open('./__output__/binaries/graph_1.pkl', 'rb') as f:
    graph: nx.Graph = pickle.load(f)

len(graph.nodes)
# Out:
# 2044

# %%
node_ids = []
node_texts = []

for k, v in dict(graph.nodes.data()).items():
    node_ids.append(k)
    node_texts.append(v['text'])

node_ids= np.array(node_ids)
node_texts= np.array(node_texts)

# %%
embedings = model.encode(
    node_texts,
    prompt_name='document',
    batch_size=16,
    show_progress_bar=True,
    normalize_embeddings=True
)
# Out:
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]

# %%
search = 'Какие философские концепции встречались в истории?'
search_emb = model.encode(
    search,
    prompt_name='query',
    normalize_embeddings=True
)

sims = embedings @ search_emb
top_k_ids = np.argsort(sims).reshape(-1)[::-1][:10]
top_k = node_ids[top_k_ids]

node_texts[top_k_ids]
# Out:
# array(['2.1. Философские концепции истории',
#        '2.1. Философские концепции истории',
#        'Глава 2. Философские концепции истории. О пониманиях истории. Цивилизационный подход. История и современность.',
#        'За пределами философии сознания эти термины используются несколько иначе.',
#        'Итак, бытиепредставляет собой одно из ключевых философских понятий, которое понимают либо как общее свойство, либо как качество всех существующих предметов, либо как нечто существующее само по себе, например как совокупность всего сущего (существующего) – вещей, веществ и отношений, либо как смысл конечного существования сознающего себя субъекта (человека). Таким образом, к этому центральному для метафизической философии понятию в истории есть как минимум три основных подхода – формально-логический, объективный и субъективный.',
#        'Имеет место масса определений философии. Но их не следует заучивать наизусть. Философию следует понимать как познавательную деятельность в рамках наблюдаемого мира посредством конструирования и производства особого рода продуктов – идей и понятий. Связь этих понятий выражается в философских теориях: учении о бытии, философии истории, теории познания, философии науки, учении о человеке, философии языка, этики, эстетики, учении о ценностях (аксиологии), социальной философии, и т. д.',
#        'Второе важное событие в истории философского анализа свободы во второй половине ХХ в. — это появление так называемых примеров Франкфурта. Гарри Франкфурт при помощи своих мысленных экспериментов попытался показать, что принцип альтернативных возможностей не является необходимым условием моральной ответственности, а, следовательно, и свободы воли.',
#        'В современной метафизике есть множество разных подходов к тому, как мы сохраняемся во времени. Есть среди них и слишком радикальные. Таким является, например, *нигилизм* – это когда говорится, что мы вообще не существуем или ни в каком смысле не сохраняемся во времени. Есть даже философы, которые вообще отрицают, что хоть что-то сохраняется во времени. Однако такого рода радикализм в философии, вероятно, редко оказывается способным объяснить некоторые очевидные факты. Рассмотрим некоторые из них:',
#        'Многие современные философы считают принцип каузальной замкнутости физического основой естествознания и лишь небольшое количество специалистов готовы его критиковать. Если физический мир самодостаточен, то для ментальных событий в нем не остается места, они *исключаются* из истории физического мира. Это называют **проблемой исключения**.',
#        '*Философия для нефилософских специальностей. Вызовы времени и ответы философии. На чем основано и как устроено это учебное пособие.*'],
#       dtype='<U19229')

# %%
[
    graph.nodes[id_]
    for id_ in top_k
]
# Out:
# [{'position': 146,
#   'text': '2.1. Философские концепции истории',
#   'node_type': <TypeReturn.LIST: 'list'>,
#   'image': None,
#   'level': 4},
#  {'position': 160,
#   'text': '2.1. Философские концепции истории',
#   'node_type': <TypeReturn.HEADING: 'heading'>,
#   'image': None,
#   'level': 4},
#  {'position': 11,
#   'text': 'Глава 2. Философские концепции истории. О пониманиях истории. Цивилизационный подход. История и современность.',
#   'node_type': <TypeReturn.TEXT: 'text'>,
#   'image': None,
#   'level': 2},
#  {'position': 1736,
#   'text': 'За пределами философии сознания эти термины используются несколько иначе.',
#   'node_type': <TypeReturn.TEXT: 'text'>,
#   'image': None,
#   'level': 4},
#  {'position': 611,
#   'text': 'Итак, бытиепредставляет собой одно из ключевых философских понятий, которое понимают либо как общее свойство, либо как качество всех существующих предметов, либо как нечто существующее само по себе, например как совокупность всего сущего (существующего) – вещей, веществ и отношений, либо как смысл конечного существования сознающего себя субъекта (человека). Таким образом, к этому центральному для метафизической философии понятию в истории есть как минимум три основных подхода – формально-логический, объективный и субъективный.',
#   'node_type': <TypeReturn.TEXT: 'text'>,
#   'image': None,
#   'level': 5},
#  {'position': 49,
#   'text': 'Имеет место масса определений философии. Но их не следует заучивать наизусть. Философию следует понимать как познавательную деятельность в рамках наблюдаемого мира посредством конструирования и производства особого рода продуктов – идей и понятий. Связь этих понятий выражается в философских теориях: учении о бытии, философии истории, теории познания, философии науки, учении о человеке, философии языка, этики, эстетики, учении о ценностях (аксиологии), социальной философии, и т. д.',
#   'node_type': <TypeReturn.TEXT: 'text'>,
#   'image': None,
#   'level': 1},
#  {'position': 1807,
#   'text': 'Второе важное событие в истории философского анализа свободы во второй половине ХХ в. — это появление так называемых примеров Франкфурта. Гарри Франкфурт при помощи своих мысленных экспериментов попытался показать, что принцип альтернативных возможностей не является необходимым условием моральной ответственности, а, следовательно, и свободы воли.',
#   'node_type': <TypeReturn.TEXT: 'text'>,
#   'image': None,
#   'level': 4},
#  {'position': 1595,
#   'text': 'В современной метафизике есть множество разных подходов к тому, как мы сохраняемся во времени. Есть среди них и слишком радикальные. Таким является, например, *нигилизм* – это когда говорится, что мы вообще не существуем или ни в каком смысле не сохраняемся во времени. Есть даже философы, которые вообще отрицают, что хоть что-то сохраняется во времени. Однако такого рода радикализм в философии, вероятно, редко оказывается способным объяснить некоторые очевидные факты. Рассмотрим некоторые из них:',
#   'node_type': <TypeReturn.TEXT: 'text'>,
#   'image': None,
#   'level': 4},
#  {'position': 1687,
#   'text': 'Многие современные философы считают принцип каузальной замкнутости физического основой естествознания и лишь небольшое количество специалистов готовы его критиковать. Если физический мир самодостаточен, то для ментальных событий в нем не остается места, они *исключаются* из истории физического мира. Это называют **проблемой исключения**.',
#   'node_type': <TypeReturn.TEXT: 'text'>,
#   'image': None,
#   'level': 4},
#  {'position': 46,
#   'text': '*Философия для нефилософских специальностей. Вызовы времени и ответы философии. На чем основано и как устроено это учебное пособие.*',
#   'node_type': <TypeReturn.TEXT: 'text'>,
#   'image': None,
#   'level': 1}]

# %%
def get_linked_type(graph: nx.Graph, node: str, t: TypeReturn):
    res = []
    visited = set()
    for linked_node in graph[node]:
        linked_data = graph.nodes[linked_node]
        if linked_data['node_type'] == t and linked_data['text'] not in visited:
            res.append(linked_data)
            visited.add(linked_data['text'])
    return res

# %% [markdown]
# '''
# <context>
#     <images>
#         Транскипции изображений
#     </images>
#     <parents>
#         Родительские заголовки
#     </parents>
#     <childs>
#         Зависимые Заголовки
#     </childs>
#     <lists>
#         Списки
#     </lists>
#     <tables>
#         Табличка
#     </tables>
#     <links>
#     Тексты, на которые ссылаются
#     </links>
#     <view>
#         Какие-то тексты
#     </view>
# </context>
# <text>
# Абра-Кадабра
# </text>
# '''

# %%
collaters= [
    (
        'images',
        TypeReturn.IMAGE,
        None
    ),
    (
        'parents',
        TypeReturn.HEADING,
        lambda root_node, to_node: root_node['level'] > to_node['level']
    ),
    (
        'childs',
        TypeReturn.HEADING,
        lambda root_node, to_node: root_node['level'] < to_node['level']
    ),
    (
        'lists',
        TypeReturn.LIST,
        None
    ),
    (
        'tables',
        TypeReturn.TABLE,
        None
    ),
    (
        'links',
        TypeReturn.FOOTNOTE,
        None
    ),
    (
        'view',
        TypeReturn.TEXT,
        None
    )
]


def collate_context(graph, node_ids: str):
    node = graph.nodes[node_ids]
    res = []

    for tag, type_ret, statement in collaters:
        linked_data = get_linked_type(graph, node_ids, type_ret)

        if statement is not None:
            linked_data = [
                l
                for l in linked_data
                if statement(node, l)
            ]

        linked_data = '\n'.join((
            l['text']
            for l in linked_data
        ))
        res.append(f'<{tag}>\n{linked_data}\n</{tag}>')
    return '\n'.join(res)


def get_document(graph, node_ids: str):
    return f'''
<context>
{collate_context(graph, node_ids)}
</context>
<text>
{graph.nodes[node_ids]['text']}
</text>
'''

# %%
print(get_document(graph, top_k[5]))
# Out:
# <context>
# <images>
# The image depicts a document with checkmarks and a gear icon. The document appears to be a checklist or a list of items, indicated by the checkmarks. The gear icon suggests that this is related to settings or configuration, possibly indicating a process for managing or adjusting settings based on the checklist.
# </images>
# <parents>
#
# </parents>
# <childs>
#
# </childs>
# <lists>
#
# </lists>
# <tables>
#
# </tables>
# <links>
#
# </links>
# <view>
# *Философия для нефилософских специальностей. Вызовы времени и ответы философии. На чем основано и как устроено это учебное пособие.*
# Существует большое количество версий понимания философии в истории, в различных странах и сообществах. История той версии философской науки, которую изучают в нашей стране, длится уже более 2,5 тысяч лет и относится к европейской культуре. Разумеется, в ней присутствуют вкрапления других культур и исторических традиций, и особенно русских, но в основе все равно лежат проблемы, сформулированные еще древними греками в VII-IV вв. до н.э.
# Правда, для целей нашего учебника исторические экскурсы и ретроспективы будут не столь важны. Мы сконцентрируемся преимущественно на тех проблемах, теориях и, главное, методах познания, которые актуальны сегодня для развития науки и технологий, и не носят только музейную и историко-культурную ценность.
# Философия имеет свой предмет, вернее, множество предметов, но все они либо глобальные, либо уникальные. Ее полюсами выступает мир-в-целом, все виды существования в мире, и человек с его бесконечным сознанием и конечной жизнью. То есть философия, с одной стороны, изучает превышающие любые чувственные возможности и представления объекты, такие, например, как «мир-в-целом», а с другой, природу “я” – единичную жизнь каждого из нас, как уникальных существ. Между этими полюсами располагаются все объекты, существа, вещества и отношения, включая пустоту и ничто, потому что философия изучает все, но с точки зрения своих, специфических подходов, методов исследования и способов выражения полученного знания.
# **Мир-в-целом** – это совокупность всех явлений, вещей, существ, веществ, частиц, энергий, процессов и отношений, существующих во времени и пространстве, и таким образом принципиально доступных чувственному восприятию, даже если они недоступны нам фактически, непосредственно или требуют для этого технического посредника (приборы или инструменты). Бесспорным признаком единства всех элементов мира как целого выступает их материальное существование, в отличие от только представляемого или мыслимого существования идеальных объектов. Сложностью для понимания такого единства является бесконечность мира и духовно-материальная природа человека, отягощенная его самосознанием, уникальностью и смертностью. Проблема выражения «мира-в-целом» в языке состоит также в том, что сам наш язык сформировался для осознания конечных единств, а понятие «бесконечности» носит чисто отрицательный характер. Поэтому понятие «мир-в-целом» выглядит как парадокс или даже оксюморон. Но это не так – проблема отношения частей к такому целому и принцип их единства являются не до конца решенными, но принципиально доказуемыми философскими «теоремами».
# Философия познает все эти элементы рельности через систему фундаментальных понятий, таких как бытие и сущее, пространство и время, единое и множественное, целое и часть, тождественное и иное, я и другой, прекрасное и возвышенное, добро и зло, правда и ложь, и т. д., но в постоянном отношении к независимой от этих познавательных средств объективной реальности.
# **Бытие** является сущностью всех видов существования, включая человека, объекты, явления, идеи и отношения. В философии бытие рассматривается как основа реальности и противопоставляется ничто. Бытие изучается в разделе онтологии как собственно учении о бытии и сущем (существующем).
# </view>
# </context>
# <text>
# Имеет место масса определений философии. Но их не следует заучивать наизусть. Философию следует понимать как познавательную деятельность в рамках наблюдаемого мира посредством конструирования и производства особого рода продуктов – идей и понятий. Связь этих понятий выражается в философских теориях: учении о бытии, философии истории, теории познания, философии науки, учении о человеке, философии языка, этики, эстетики, учении о ценностях (аксиологии), социальной философии, и т. д.
# </text>
